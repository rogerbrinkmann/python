# %%
import pandas as pd

# %%
pd.set_option('max_colwidth', 300)

# %%
df = pd.read_csv("data.csv", sep=";", encoding="ansi")

# %%
df.loc[df["Wertstellungstag"].str.contains("congstar"),["Wertstellungstag"]]
# Out:
#                                                                                                                                                                                                                                                          Wertstellungstag
# 24.01.2020                                       congstar - eine Marke der Telekom Deutschland GmbH SEP A-BASISLASTSCHRIFT SVWZ+ OT HR sonstige Zahlung Kundenn ummer 2205336144/RG 7298465 628 vom 17.01.20 EREF+ 3819 382624 MREF+ MA14633355 CRE D+ DE93ZZZ00000078611
# 23.12.2019                                       congstar - eine Marke der Telekom Deutschland GmbH SEP A-BASISLASTSCHRIFT SVWZ+ OT HR sonstige Zahlung Kundenn ummer 2205336144/RG 7294754 901 vom 16.12.19 EREF+ 3857 120097 MREF+ MA14633355 CRE D+ DE93ZZZ00000078611
# ...

# %%
df.head()
# Out:
#            Buchungstag  \
# 20.02.2020  20.02.2020
# 20.02.2020  20.02.2020
# 18.02.2020  18.02.2020
# 18.02.2020  18.02.2020
# 17.02.2020  17.02.2020
#
#                                                                                                                                                            Wertstellungstag  \
# 20.02.2020  SCHUHPARK 19.02.2020 17.44.35 OFFLIN EUR      39,95 EC          61448413 044598 PAN 6726305500029536690 Schuhpark Fascies//Soest/DE 002 12/2022 GIROCARD CIC...
# 20.02.2020  Kress GmbH + Co. KG Soest SEPA-BASISLASTSCHRIFT SVWZ+ CGDD kartenbasierter Lastsc hrifteinELV54309390 18.02 1 7.35 ME2 EREF+ T02002185430 9390179922 MREF+ 5...
# 18.02.2020  ALDI GmbH + Co. KG WERL 17.02.2020 16.21.40 375880 EUR      23,78 EC          54406859 470406 PAN 6726305500029536690 ALDI SAGT DANKE 13 003//Soe 002 12/202...
# ...
